# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#facebookの依存関係をpagerankで表示" data-toc-modified-id="facebookの依存関係をpagerankで表示-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>facebookの依存関係をpagerankで表示</a></div>

# %% [markdown]
# # facebookの依存関係をpagerankで表示
#
# [データサイエンティストが知っておくべき5つのグラフアルゴリズム](https://qiita.com/baby-degu/items/904a0e832d535d9e4b31?utm_source=Qiitaニュース&utm_campaign=bcd6886b40-Qiita_newsletter_382_10_09_2019&utm_medium=email&utm_term=0_e44feaa081-bcd6886b40-33455193)
# に例がある．
#
# 少し追記
# 1. https://snap.stanford.edu/data/egonets-Facebook.html からfacebook-combined.txtをDL
# 1. networkxとmatplotlibをimport
#
# fileをreadで失敗したが，jupyterの再起動で認識．

# %%
import networkx as nx

# reading the dataset
fb = nx.read_edgelist('./facebook_combined.txt', create_using = nx.Graph(), nodetype = int)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

pos = nx.spring_layout(fb)
import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 15)
plt.axis('off')

nx.draw_networkx(fb, pos, with_labels = False, node_size = 35)
plt.show()
